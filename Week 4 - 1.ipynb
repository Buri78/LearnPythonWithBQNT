# %% [markdown]
# <span style='color: Rgb(255,160,40); font-size: 48px'> Python with BQNT<img src='logo.png' height='48' width='200' align='right' style="padding: 20px"> </span> <br>
# <span style='color: grey; font-size: 13px'> Information in this tutorial has been collected from various sources and condensed into a single notebook.
#  </span>

# %% [markdown]
# ### Pandas ###
#
# Pandas = Python Data Analysis Library (actually it's coming from PANelDAta)
#
# Built on top of Numpy, it provides even more convenient data structures (mainly Series and DataFrame). Python can now compete with R and its dataframes!
#
# Import Pandas (```pd``` is a conventional abbreviation for pandas)
#
# ```python
# import pandas as pd
# ```

# %% [markdown]
# #### Pandas DataFrame ####
#
# **DataFrame** is a 2D table with labelled axes (both rows and columns). Think of it as a collection of ```Series``` or a database table.

# %% [markdown]
# ** Creating DataFrame **
#
# You may create DataFrame from ```list```, ```dict```, JSON, CSV, Excel, etc.
#
# *Try this:*
#
# From ```dict```. Note your column may be in a different order. You may specify ```columns=['name', 'age']``` parameter.
#
# ```python
# data = {
#     'name': ['Paul', 'Georges', 'Ringo'],
#     'ages': [22, 21, 23]
# }
# pd.DataFrame(data)
# ```

# %%
import pandas as pd

# %%
# Type code here
data = {
    'name': ['Paul', 'Georges', 'Ringo'],
    'ages': [22, 21, 23]
}
pd.DataFrame(data)
# Out:
#       name  ages
# 0     Paul    22
# 1  Georges    21
# 2    Ringo    23

# %% [markdown]
# *Try this:*
#
# From ```list```
#
# ```python
# pd.DataFrame([["Paul", 22], ["Georges", 21], ["Ringo", 23]], columns=["Name", "Age"])
# ```

# %%
# Type code here
pd.DataFrame([["Paul", 22], ["Georges", 21], ["Ringo", 23]], columns=["Name", "Age"])
# Out:
#       Name  Age
# 0     Paul   22
# 1  Georges   21
# 2    Ringo   23

# %% [markdown]
# *Try this:*
#
# From CSV (CAC + TPXC30 + DJIA data as of 6 July 2017)
#
# ```python
# df = pd.read_csv("stock_data.csv")
# ```

# %%
# Type code here
df = pd.read_csv("stock_data.csv")
df
# Out:
#             Ticker Currency              Name                        Industry  \
# 0    AIR FP Equity      EUR         AIRBUS SE             Aerospace & Defense
# 1    SAF FP Equity      EUR         SAFRAN SA             Aerospace & Defense
# 2     BA UN Equity      USD     BOEING CO/THE             Aerospace & Defense
# 3    UTX UN Equity      USD  UNITED TECH CORP             Aerospace & Defense
# 4   6902 JT Equity      JPY        DENSO CORP                 Auto Components
# ..             ...      ...               ...                             ...
# 95  8031 JT Equity      JPY       MITSUI & CO  Trading Companies & Distributo
# 96  8058 JT Equity      JPY   MITSUBISHI CORP  Trading Companies & Distributo
# 97  9433 JT Equity      JPY         KDDI CORP  Wireless Telecommunication Ser
# 98  9437 JT Equity      JPY    NTT DOCOMO INC  Wireless Telecommunication Ser
# 99  9984 JT Equity      JPY  SOFTBANK GROUP C  Wireless Telecommunication Ser
#
#       Close     1YR TR     5YR TR
# 0     73.91  55.446760  23.546960
# 1     81.89  45.419720  26.576310
# 2    201.81  64.156520  25.527950
# 3    122.79  24.007990  13.277350
# 4   4793.00  46.556520  14.945050
# ..      ...        ...        ...
# 95  1609.00  37.663200   9.848548
# 96  2383.00  38.238880  10.976230
# 97  2988.00  -5.899152  30.899870
# 98  2644.00  -5.470530  18.942730
# 99  8960.00  60.605750  26.313730
#
# [100 rows x 7 columns]

# %% [markdown]
# ** Explore the data **
#
# *Try this:*
#
# ```python
# df.head()
# df.tail(3)
# df.T
# df.shape
# df.size
# df.describe()
# df.info()
# df["Currency"].value_counts()
# ```

# %%
# Type code here
df["Currency"] = df["Currency"].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
# Ticker      100 non-null object
# Currency    100 non-null category
# Name        100 non-null object
# Industry    100 non-null object
# Close       100 non-null float64
# 1YR TR      99 non-null float64
# 5YR TR      97 non-null float64
# dtypes: category(1), float64(3), object(3)
# memory usage: 5.0+ KB

# %% [markdown]
# ** Index **
#
# *Try this:*
#
# ```python
# df.index
# df.columns
# ```

# %%
# Type code here
df.columns
# Out:
# Index(['Ticker', 'Currency', 'Name', 'Industry', 'Close', '1YR TR', '5YR TR'], dtype='object')

# %% [markdown]
# *Try this:*
#
# Note 'Ticker' is not in the columns but is the index. Therefore the below would fail:
#
# ```python
# df['Ticker']
# ```

# %%
# Type code here

# %% [markdown]
# *Try this:*
#
# To look up if a ticker is available:
#
# ```python
# 'AAPL UW Equity' in df.index
# ```

# %%
# Type code here
'AAPL UW Equity' in df.index
# Out:
# False

# %% [markdown]
# *Try this:*
#
# What does ```reset_index()``` and ```set_index()``` do?
#
# ```python
# df.reset_index()
# ```

# %%
# Type code here
df.reset_index().set_index('Ticker').head()
# Out:
#                 index Currency              Name             Industry  \
# Ticker
# AIR FP Equity       0      EUR         AIRBUS SE  Aerospace & Defense
# SAF FP Equity       1      EUR         SAFRAN SA  Aerospace & Defense
# BA UN Equity        2      USD     BOEING CO/THE  Aerospace & Defense
# UTX UN Equity       3      USD  UNITED TECH CORP  Aerospace & Defense
# 6902 JT Equity      4      JPY        DENSO CORP      Auto Components
#
#                   Close    1YR TR    5YR TR
# Ticker
# AIR FP Equity     73.91  55.44676  23.54696
# SAF FP Equity     81.89  45.41972  26.57631
# BA UN Equity     201.81  64.15652  25.52795
# UTX UN Equity    122.79  24.00799  13.27735
# 6902 JT Equity  4793.00  46.55652  14.94505
